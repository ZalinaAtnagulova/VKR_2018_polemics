# %%
from sklearn import cluster
import networkx as nx
from collections import defaultdict
import matplotlib.pyplot as plt
from matplotlib import cm
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.metrics.cluster import normalized_mutual_info_score
from sklearn.metrics.cluster import adjusted_rand_score
import pickle

# %%
with open ('polemic_comments.pkl', 'rb') as fp:
    polemic_comments = pickle.load(fp)

# %%
"достать все комментарии в каждом кластере"
only_comments_by_cluster = {}
for clstr in polemic_comments:
    clstr_comments = []
    cntr_articles = 0
    for article in clstr[1]:
        cntr_articles += 1
        comments_arr = article[2]
        #print(len(comments_arr))
        if len(comments_arr) != 0:
            #print(comments_arr)
            for inner_tuple in comments_arr:
                #print(inner_tuple)
                for comment_text in inner_tuple[1]:
                    clstr_comments.append(comment_text)
    cntr_comments = len(clstr_comments)
    print(clstr[0], cntr_articles, cntr_comments, cntr_comments/cntr_articles)
    only_comments_by_cluster[clstr[0]] = clstr_comments
# Out:
# 6 18 74 4.111111111111111
# 7 28 87 3.107142857142857
# 12 13 30 2.3076923076923075
# 16 7 31 4.428571428571429
# 20 32 443 13.84375
# 21 20 248 12.4
# 24 8 47 5.875
# 30 68 1521 22.36764705882353
# 33 17 985 57.94117647058823
# 34 16 334 20.875

# %%
import nltk, math, codecs
from gensim.models import Doc2Vec
from nltk.cluster.kmeans import KMeansClusterer
import re
import pymorphy2
from datetime import datetime
from sklearn.metrics.pairwise import cosine_distances

fname = 'noStopLemma_PV-DBOW_wrd-vec_1it_2win_6mincount_alpha25-25_sz80.model'

model = Doc2Vec.load(fname)

morph = pymorphy2.MorphAnalyzer()
# Out:
# C:\Anaconda\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
with open('stopwords.txt', 'r', encoding='utf-8') as f:
    txt = f.read().split('\n')
stw = set(txt)

# %%
def preprocess(str):
    # remove links
    str = re.sub(r'http(s)?:\/\/\S*? ', "", str)
    return str


def preprocess_document(text):
    #text = preprocess(text)
    fixedNoStop = []
    fixed = ''.join([x if x.isalnum() or x.isspace() else " " for x in text ]).split()
    for fix in fixed:
        if fix not in stw:
            fix = morph.parse(fix)[0].normal_form
            fixedNoStop.append(fix)
    return fixedNoStop

start_time = datetime.now()

#NUM_CLUSTERS = 15

#data = <sparse matrix that you would normally give to scikit>.toarray()

#corpus = codecs.open('test_headlines_short.txt', mode="r", encoding="utf-8")
#for cluster in only_comments_by_cluster:
#    print(len(only_comments_by_cluster[cluster]))
#lines = ['Бог даст - и во втором победит.', 'В не всякого сомнения, победа на выборах за Марин Ле Пен, какие бы козни её не чинили...', 'Как с Трампом. 61% из специальной выборки, исключающей 100% тех, кто точно против.', 'Макрон - Президент Франции! Трамп - ненаш! Черногория в НАТО! Обидно, да, рос-патриоты?))))', 'ещё не вечер . А этим заказным опросам грош цена в базарный день .', 'Ага, верю-верю! Клинтоншу тоже, согласно опросов, поддерживало большинство, и победа была гарантирована. И где теперь те опросники, и их опросы- прогнозы?))', 'После выборов,если будет ставленник пиндосии Макарон, то французов мне жалко. И больше они для меня не будут представлять Великую Францию.', 'Сергей Викторов, Ну, зачем ты так жестоко с ними? Они же очень сильно расстроятся, что не представляют для рос-патриота сереги Великую Францию)))))', 'До уличного светила, что называется, это дело народа Франции.', 'Опрос про Клинтон вспомнился...', 'Александр Михайлов,  Про Париж точно знаешь? Часто там бываешь, рос-патриот?))))', 'Александр Михайлов, Сколько боярышника принял, рос-патриот,  чтобы в соседнем дворе "Париж" увидеть?))))']
lines = only_comments_by_cluster['20']
for line in range(len(lines)):
    lines[line] = lines[line].lower()
#lines = corpus.read().lower().split('\r\n')
#count = len(lines)

vectors = []

print("inferring vectors")
duplicate_dict = {}
used_lines = []
for i, t in enumerate(lines):
    if t not in duplicate_dict:#i % 2 == 0 and
        duplicate_dict[t] = True
        used_lines.append(t)
        vectors.append(model.infer_vector(preprocess_document(t)))

print("done")
# Out:
# inferring vectors
# done

# %%
distances = cosine_distances(vectors)

# %%
#algorithms['affinity'] = cluster.AffinityPropagation(damping=0.6)
affinity = cluster.AffinityPropagation(damping=0.6, affinity = 'precomputed')
affinity.fit(distances)
# Fit all models
#for model in algorithms.values():
#    model.fit(edge_mat)
#    results.append(list(model.labels_))
# Out:
# AffinityPropagation(affinity='precomputed', convergence_iter=15, copy=True,
#           damping=0.6, max_iter=200, preference=None, verbose=False)

# %%
#result = []
result = list(affinity.labels_)
cluster_centers_indices = affinity.cluster_centers_indices_
labels = affinity.labels_
n_clusters_ = len(cluster_centers_indices)

# %%
cluster_centers_indices[0]
# Out:
# 5

# %%
clustersizes = []

def distanceToCentroid():
    all_distances = []
    for i in range(0, NUM_CLUSTERS):
        clustersize = 0
        for j in range(0, len(result)):
            if (result[j] == i):
                clustersize+=1
        clustersizes.append(clustersize)
        dist = 0.0
        centr = kclusterer.means()[i]
        for j in range(0, len(assigned_clusters)):
            if (assigned_clusters[j] == i):
                dist += pow(nltk.cluster.util.cosine_distance(vectors[j], centr),2)/clustersize
        dist = math.sqrt(dist)
        all_distances.append(dist)
        #print("distance cluster: "+str(i)+" RMSE: "+str(dist)+" clustersize: "+str(clustersize))
    return all_distances

def nClosestToCentroid(cluster_id, n):
    #clustersize = len(get_titles_by_cluster(cluster_id))
    #centr = kclusterer.means()[cluster_id]
    centr = vectors[affinity.cluster_centers_indices_[cluster_id]]
    distances = []
    for j in range(0, len(result)):
        if (result[j] == cluster_id):
            distances.append((used_lines[j], nltk.cluster.util.cosine_distance(vectors[j], centr)))
            
    #print(distances)
    distances = sorted(distances, key=lambda tup: tup[1])
    return distances[:n]


def get_titles_by_cluster(id):
    list = []
    for x in range(0, len(result)):
        if (result[x] == id):
            list.append(used_lines[x])
    return list

def get_topics(titles):
    from collections import Counter
    words = [preprocess_document(x) for x in titles]
    words = [word for sublist in words for word in sublist]
    #filtered_words = [word for word in words if word not in stw]
    count = Counter(words)
    print(count.most_common()[:5])


def cluster_to_topics(id):
    get_topics(get_titles_by_cluster(id))

# %%
#cluster_to_topics(clstr)
for clstr in range(n_clusters_):
    #cluster_to_topics(clstr)
    #print(get_titles_by_cluster(clstr))
    n = round(len(get_titles_by_cluster(clstr))/3)
    print(n)
    print(nClosestToCentroid(clstr, n))
#print('####\n')

#посмотреть выдачу
# Out:
# 30
# [('мальчиш-плохиш совершенствует свою рогатку :-))', -2.2204460492503131e-16), ('замените пожалуйста в ех татжтков и узбеков на рабочих из кндр.', 1.0239170902249537), ('нужно расширить экспорт в кндр всей продукции. это деньги в нашу страну!', 1.0705560264308986), ('игорь ,, та ни шо.', 1.0706994404899213), ('kymapc, никто там ничем "жахать не будет. вы что серьезно не понимаете что там происходит? штатам выгодна напряженная обстановка рядом с китаем. чтобы иметь предлог для нахождения там своих военно-морских сил. и именно по этому они провоцируют северную корею на новые выпады, проводя там "учения", якобы для защиты союзников по нато.=вы вообще в курсе что ирак разрушили демократичные и цивилизованные страны под сфальсифицированным предлогом того что саддам может использовать оружие массового поражения. после чего на его территории и образовался игил. в результате тысячи невинных смертей, сотни тысяч беженцев.вы хотите чтобы мы с такими вот неадекватами дружили? которые уничтожают чужие далекие страны и плодят террористов?', 1.073009802536979), ('уверен в том, что амеры в принципе не понимают что и как должно делаться ведущими странами для сохранения мира на нашей планете! и это, увы, неизлечимо!..', 1.0830335859503641), ('а на чём абэ считает? на калькуляторе. пусть не лезет не в своё дело. уберут американские базы из японии и считают...', 1.0950124334230906), ('идея хорошая, только кто агрессора принудит, сша не станут слушать. нужен серьёзный союз европы, россии и китая, отменяйтесь санкции, господа ес.', 1.0996678875282528), ('сколько можно идти на поводу у сша, а может наоборот встать на защиту кндр и подтянуть флот к гуама и окинава.', 1.1050193088245579), ('давно пора , россию и так ни во что не ставят все цивилизованные страны, так мы ещё помогаем всяким кровавым тиранам ...', 1.1094503281431916), ('нужно прекратить поставки нефти в саму японию, а также в те страны, что ввели санкции против россии и пустить её (нефть) на свои нужды (понижение цен на топливо, энергоресурсы и т.п. для собственного населения). а то россия (сидя на нефти и газе) является сырьевым придатком развитого забугорья забывая о себе. хвати', 1.1126941689309333), ('как только ким разоружится, сша сразу нападут.', 1.1185418754950065), ('ну дают... курить меньше надо. сами только что испытывали.', 1.1199228508803252), ('главкин, россия тоже получила санкции за ядерные испытания в кндр, т.е. россия голосовала за санкции против себя) в отличие от россии, украине передавать движки в кндр незачем. другое дело, если бы украина поменяла их на ядерные боеголовки из кндр, но такого не было.', 1.1205267884214405), ('а, эта дама, что беспокоится о ракетах кндр? лучше думала о том, что делают ядерные силы и про сша в европе?', 1.1214921350445395), ('в россии смекнули, что лучше прислушаться к голосу разума и поддержать позицию сша. хоть тут прекратили блокировку совбеза ooh и провокации!', 1.1217669234803846), ('и родился у рокетмена, в минуты этого непростительного пролёта,  наследник свободолюбивой империи балды - будующий неустрашимый ядерный молотобоец  ким чен ссун)', 1.123550286733465), ('heinrich von plauen, америка - голос разума??? эти окупанты по всему миру сеют только хаос и войны! а куда боятся сунуться категорически осуждают и просят помощи у мирового сообщества! вот только печально что лидеры многих стран ведутся на их "голос разума"!', 1.1237965981565086), ('arseny, а вы куда?', 1.1251613215117962), ('тарас рязанцев, вы не вникаете в суть коммента. я написал-то потому что все тут пишут "че удумали япошки, нам указывать". кндр принадлежит к ряду беднейших стран мира, занимая 213-е место из 230 по ввп на душу населения. почитайте о кндр. это тоталитарная, беднейшая (у людей нечеловеческие условия жизни) и фанатизированная страна. нечего додумывать, придумывать и мылить себе мозги теликом. нам пофиг куда толкать нефть, лишь бы покупали. вот это правда))', 1.1314272833340415), ('fazer, хочешь сказать, что в индии, китае, бразилии - "диктатуры", а " ...
# 6
# [('что-то эта федерика какая-то запуганная. неужели из-за этой ракетки?!', 0.0), ('абэ кто-то сказал (ввел его в заблуждение), что корейцы заправляют свои ракеты нефтью. поэтому решил наложить санкции на нефть. он вместе с трампом никак не может понять, что в кндр живут тоже люди - такие же, как в сша, и европе. когда до них это дойдет, начнется разоружение. но к сожалению, такое озарение наступит не скоро.', 1.0860049442759285), ('если кндр может противостоять внешней агрессии, то олигархическая россия не может противостоять идеологическому разложению в обществе.', 1.0997285465585229), ('при чем военный ответ на испытания "пустой" болванки. кндр  может в космос полететь хочет. спутник на орбиту вывести, космонавта отправить. это шаги в ракетостроительстве которые прошли все космические державы. почему одним можно , а другим нельзя. да не уровновешенный в высказываниях руководитель страны, а в америке что на заре создания ядерного оружия нормальные были? те вообще на людях бомбы испытали. у япошек память короткая, не только рост.', 1.1157928470861445), ('rem.rem-kompa, клоун. речь идёт не о ценах, а о поставках. туда никто кроме вовы нефть не поставляет - здесь нет речи о мировых ценах, уважаемый! когда же вы, бараны, думать начнете...', 1.1168872709269912), ('брехня! для использования "кибероружия", нужно по крайней мере подключение к атакуемым системам. все уважающие себя оборонные системы любых стран (исключая самих амеров, наверное)), имеют только внутреннюю защищенную сеть, скорее всего проводную. без доступа в интернет, которым амеры так всех пугают. ну, и не надо забывать о "северокорейских хакерах", которые сами накажут любого "кибервооруженного амера"!) так что пусть эксперементируют дальше.', 1.1337043383844854)]
# 25
# [('вы куда лезите?', 2.2204460492503131e-16), ('кндр надо предоставить с-400 для защиты себя, а заодно россии и китая, и объявить побольше акватории бесполетной. сша планируют войнушки только вблизи их границ. южная америка, ближний восток и африка считаются вполне демократичными или ставшими на путь исправления.', 1.0688918315048956), ('vip.nikolay55, всем миром?кто перечислите.осуждены нацисткие преступники на нюрнбергском процессе,а вы мне фашисткую сша говорите,кем они признаны фашистким государством?в каком году?каким всем миром осуждены?в каком году?что за процесс?', 1.0768874684243215), ('дежавю... киев и сеул видимо с одной бумажки речь читали', 1.0984931058748666), ('глупцы, силовое давление ничего не даст, будет только хуже. либо мирно договариваться, либо военное вторжение. воевать кишка тонка, вывод очевиден.', 1.0986923997633766), ('штаты не согласятся. им там мир не нужен!', 1.1019601458116954), ('игорь ,, как стелс ф-117 в югославии, или где там было дело?))) или как в анекдоте: целились в ворону, а тут ни в тему самолёт "исключительных" между вороной и ракетой возник, вот и сбили?))', 1.1061117677507812), ('leha.sakharov.90, не поймёшь, то ли ренжеры, то ли самураи.', 1.1230582233190729), ('вот умеют в\\на украине рассмешить весь мир.)))))) я так минут 30 не то чтобы смеялся, просто ржал))))), представляя рычаги влияния украины.))))))))))украина будет использовать все возможные рычаги влияния в качестве непостоянного члена совета безопасности оон для возвращения кндр в международное правовое поле.какое влияние украины!!!!!, какие рычаги у попрошаек и должников!!!!!.сами в своей стране скоро свет начнут отключать (электричество кончится), а еще хотят кого-то вернуть в международное право.)))) для начала, попробуйте себя вернуть в международное право (кастрюлеголовые), с тайными тюрьмами сбу, продовольственная и электрическая блокада крыма и т.д..', 1.1252469413023458), ('ну с кндр надо что-то делать. это страна-концлагерь, где вождь и номенклатура купаются в безумной роскоши, а народ умирает от голода в буквальном смысле. и где за анекдот про кима могут всю семью уничтожить. ну в общем классика тоталитаризма. такому нет места в современном мире. режим кима должен быть уничтожен (как можно более мирным способом), а население после 10-20 лет реабилитации воссоединено с югом.', 1.1271628762115866), ('mal-anv, план разработали россия и китай...просто видимо германия боится говорить что поддерживает "российский" план...либо это "профессионализм" автора статьи....', 1.129158725970856), ('а при чем здесь россия ? в статье речь о диалоге между китаем и германией. там нет ни слова о россии.', 1.1337409587365976), ('премьер какой-то региональной страны имеет наглость указывать россии, что и как делать в отношении кндр! дудки!', 1.1340974801339656), ('baltica78com, а сталин что был против или наши солдаты были против?сколько наших погибло при освобождении китая и сколько еще бы погибло если бы не эти бомбы?', 1.1343279956042154), ('ты с алканафтом с окраины лучше разберись,чтоб перестал геноцид устраивать!!!!!', 1.1380696410858162), ('sch.shurikov, у любого зрк есть  "слепые зоны", обусловленные особенностями рельефа и некоторыми техническими моментами. эти зоны закрывают другие зрк средней и малой дальности, панцирь например. я предпочитаю верить фактам, а не слухам', 1.142627071393399), ('sanruso, как раз с теми,а у амеров друзей нет,есть лишь рабы и вассалы!', 1.1429171228895221), ('северная корея ничем не заслужила этих провокаций, вообще, такого отношения мирового сообщества. они независимы и в этом их сила, и за это на них окрасилось пол земного шара. а по факту, эта половина земного шара - в той или иной мере зависима от своего хозяина', 1.151833222665767), ('rim, если  даже  такое  случится  ,  то  это  не  30  годы  и  голодомор  на  украине  ,  это  только  хуже  для  ына  ,  решением  совбеза   оон будет введена  миссия  для    решения  проблемы  по существу.', 1.1527605088412676), ('- у самой голова фарфоровая, ...
# 42
# [('нужно взять под козырек и ответить есть!', -2.2204460492503131e-16), ('елена ерофеева, пока побаиваются, вдруг кндр на америкосовскую агрессию ответит? они же давно уже по личику не получали.', 1.0661856483997618), ('mal-anv, а что не понятно? все прекрасно знают,что китай и россия действуют впаре. просто не стали упоминать россию,дабы не провоцировать русофобов на новые нападки. кому это надо? главное-цель!!! а не средства их достижения.', 1.0806958225857981), ('и чего япоши возмущаются? наоборот радоваться должны! что ракета без боеголовки...', 1.0839408858625852), ('ни с теми дружбу водим.', 1.0842336268446586), ('как быстро японцы хиросиму забыли...', 1.0842491055218866), ('киму надо было так же в ответ провести демонстацию военных возможностей кндр - сбить эти самолёты.', 1.0905987316979244), ('ведь на самом деле, северная корея не несет угрозу кому-либо. кндр всего лишь защищает свою государственность и свою независимость. политика сша и ее партнеров заставляют северную корею вооружаться и быть на чеку. и это правильно...', 1.0962273990732723), ('fazer, американские военные базы на украине угрожают россии, а не северной корее. сказать чем... или сами догадаетесь? а вы забыли про хиросиму и нагасаки?', 1.1020947082915766), ('romanenko.sb,  назови хоть один северокорейский товар!', 1.1026042430147933), ('о, да! бойся, ким чен ын, ищи на карте вукраину!', 1.1035751921357135), ('пусть командует в японии.', 1.1039270757926511), ('не, мы не можем, мы под санкциями, экономика в клочьях, да ещё агрессор. вы прибалтов попросите, они поддержат.', 1.109718647648573), ('mal-anv, россия уже сама не знает, как показать хотя бы своим гражданам , что ее мнение никого в принципе не интересует , и его никто по факту и не спрашивает .', 1.1107721867279663), ('георгий головлёв, ну, не тому ответил и что будет?', 1.1130274583511319), ('георгий головлёв, для бога всё катит, он различий не делает. у него свои универсальные категории, заповеди и прочее', 1.1171550986452032), ('а то с завтрашнего дня прекратят закуп сала в кндр.', 1.117967799753129), ('экономическое  эмбарго  гораздо  эффективнее,  в частности  ,  запрет  на  использование  корейской  рабочей  силы и прекращение  торговли с  сев.кореей  ,  резко уменьшит  поступление в казну  , и  соответственно  , уменьшит возможности  для  вливаний в  разработку  оружия.', 1.118565442255665), ('духовная скрепа, с 9 августа по 2 сентября 1945 года советская армия потеряла 12 тысяч военнослужащих, а япония - больше 80 тысяч! и еще больше 600 тысяч военнопленных! и никаких атомных бомб ссср в манджурии не применял!', 1.1226510785757919), ('vip.nikolay55,еще раз,почему не судите сша если судить надо?чего ждете?всех союзников фашисткой сша и ссср тоже тогда судить,потому что они пособники в этом случае и в суд ни один из них не подал !так в чем ваше затруднение ответить на вопрос мой,который вы обходите придумывая пустые отговорочки?вас вопрос мой в тупик поставил', 1.1254549923210824), ('igor.tsytsura.00, это если они войну выиграют. война с кореей экономику не перезагрузит, так как итоговый профит от такой войны довольно мал, надо воевать с кем-то по-серьезнее, вроде россии или китая. а такую войну даже своими руками они могут не выиграть, не говоря уже о чужих. и даже так - если начнут такую войну, они только ускорят падение доллара. кто будет торговать в валюте агрессора? да никто. конфликт просто раздувается намеренно, чтобы разместить больше thaad и продать больше вооружений, держать больше военный контингент. а война им как раз не нужна, это затратно очень, а там дураков нет - деньги они считают хорошо.', 1.1257161757051866), ('alexsyst ne-ne, давай сравним северокорейский шовинизм и японский... ок? кто сейчас весь восток в страхе держит?', 1.1262807442320188), ('fazer, да. хорошо, что испытали. а что испытывали фашисты, когда наши приближались к берлину .... вы еще фашистов пожалейте. мирового агрессора - америкосов всегда найдутся желающие пожалеть.', 1.1272243396394837), ('андрей  васи ...
# 7
# [('bugaevil, это да!', 2.2204460492503131e-16), ('arsil, после реформы совбеза оон войдет однозначно вместе со швецией, индией, германией, мексикой, либо бразилией, какими-нибудь из арабов.', 1.0349167758906292), ('ну да, у японцев спросить забыли. для начала пусть япония вышвырнет пиндосовские военные базы со своей территории. а потом уж и поговорить можно о чем-то.', 1.0883549098325622), ('mix - max, вот именно, чего тогда их бояться, если никакого духа.', 1.0927204387546905), ('mal-anv, в совбезе оон', 1.0970654671268751), ('пиндосы испугались, кндр дала чётко понять, что будет, если сша не отвяжутся. теперь давят на всех, на кого могут, чтобы не самим спровоцировать их на ответные действия. китай, россия, вы плохо с ними боретесь!... очень хитрожопая позиция!', 1.115063644509086), ('игорь напротив калифорнии есть разломчик тектонических плит.', 1.1295560807579241)]
# 7
# [('как-нибудь без вас', -2.2204460492503131e-16), ('andy nov, самураи нынче уже не те...', 1.0882900887999469), ('нобелевскую премию мира не вручили сразу, вот и результат. срочно вручить и отправить по назначению, обратно в приют. привык, наверное, у себя вести как глава опг.', 1.0923566398884164), ('если хотят, то пусть заплатят россии за неустойку. если будет гарантирована безопасность  и не вмешательство во внутренние дела, то кндр не будет напрягаться. пример югославии, ливии, сирии, ирана , ирака, украины  доказывают о необходимости иметь ядерное оружие, гаранте мира. ссср не проиграл холодную война, просто переформатировался.', 1.0994884696903875), ('scheglovm, а я задался другим вопросом: «почему мнение исходного комментария поддерживается, а наши с вами комментарии скатываются вниз?» вроде все обращены к автору статьи не безосновательно. правда, каюсь, мой комментарий не без сарказма, но все же в одном направлении (просьба не смешивать с патриотическими чувствами). однако в итоге мы имеем такие разные результаты... есть предположение, что новостные каналы настраивают людей таким образом, что прочитав что-то не понятное и вообразив, что речь идет о критике в адрес россии, мгновенно следует негативная реакция! с таким подходом, подкрепленным не желанием анализировать информацию, как бы не скатиться к 35-му году...) это не я вам говорю, а сама математика (с)', 1.1004113644983931), ('иван иванов, вы романтик))', 1.1119797421804525), ('arthur booo, "стало историей которую бы все забыли""забывать историю" свойственно вашему народу.', 1.1233286762032086)]
# 8
# [('тут что все после лоботомии ? ей где люди ?', -2.2204460492503131e-16), ('jiovanni di strada, а чего тут присматриваться. военный бюджет сша больше всех вместе взятых. военных баз по всему миру натыкано американских немеряно.чего тут присматриваться?', 1.0877906818229879), ('myaksom, не напомнишь, кто там проиграл во второй мировой?', 1.1160837483266346), ('алексей, и южная корея и тайвань развили свою экономику именно в периоды, когда у них во власти стояли диктаторы (ли сын ман и чан кай ши, соответственно). просто эти диктаторы были друзьями сша и потому им никто не мешал развивать свою экономику. когда кндр никто не мешал развивать экономику у них был ежегодный прирост ввп 10%.  потом сша решили начали пытаться внедрить демократию в кндр. именно тогда кндр и начала развивать свою оборону и тогда у неё начались проблемы с экономикой.', 1.1162122225331701), ('"... нефть необходима не только для ракетных пусков, ..."нефть, для пуска ракет? баллистических? страшно представить на чём у таро коно работает телевизор. от буржуйки что ли?', 1.1219155872946456), ('alex4344944, у зимбабве нет ни ядерного оружия, ни тем более средств доставки. запад сам заставил кндр заниматься разработками, чтобы обезопасить свое государство', 1.1229749963132332), ('i-egorov, что в сша сказали, то попугаи и повторяют. лицемеры и лжецы!', 1.1238614626033958), ('у путина в друзьях остались только диктаторы и исламские шейхи на востоке...', 1.1244209986888558)]
# 12
# [('mal-anv, тот же вопрос.', 0.0), ('алексей, у кнр никаких связей нет и она  никогда и никаких связей ни с какой страной не допустит. однако как она развивается!!!', 1.0627411625034262), ('бороться с мбр-ам с помошчу компа... ну да, пикольно!совсем в русском стиле - несиметрический ответ )))', 1.0786097463763002), ('через них ракеты перелетают, а они о какой то давилке, которая не выросла. от слова совсем.', 1.091819461660106), ('духовная скрепа, америкосов и осуждают. америкосов судить нужно будет, когда мир из победит. действия американских фашистов  нельзя оставлять безнаказанными. а наших советских солдат мне осуждать не за что, они массово не уничтожали женщин и детей, мирное население. америкосы свои зверства с нами не согласовывали. попытайтесь связать массовое убийство мирного населения японии и жизни наших солдат? это иезуитская логика, достойная идеологии геббельса и гитлера.', 1.0936548388170864), ('а с какого это перепугу мы должны подтягивать им штаны? американцы сами заварили эту кашу, сами пусть её и расхлёбывают.', 1.1046394320781432), ('не помню, чтобы япония входила  в совбез оон', 1.1152002854516281), ('духовная скрепа, любезнейший, вы попутали берега. америкосы испытывали ядерное оружие на японцах. мы вели войну с фашистами. фашизм и военные преступления америкосов осуждены всем миром уже. вы, что из незалежной вещаете или от их америкосовских покровителей, что вас так волнует оправдание америкосовских преступлений? америкосы на этой войне деньги зарабатывали. где вы видели их серьезные военные действия? так, видимость только. так что, американцам нет прощения за их военные преступления, уничтожение мирных жителей в массовом количестве. примите это спокойно.', 1.1156244470166456), ('духовная скрепа, ещё до взрывов в хиросиме и нагосаки японцы готовы были сдаться...ссср уже наступал и сша...они готовы были капитулировать и без ядерного удара...сша знали об этом, но просто использовали японию как полигон...', 1.1176083799136651), ('духовная скрепа, особенно америкосы помогли, когда уничтожили мирное население? детей, стариков, женщин, ....?', 1.1194975939153704), ('mal-anv, блин, ребята, когда уже научитесь мозги включать?человек разговаривал по телефону с китайским министром, понятное дело что он про китай говорил, не упоминая россию. причём россия в разговоре наверняка упоминалась, но информационное сообщение готовили китайские работники агитпропа, которые конечно же написали то что им было выгодно.к тому ж за пару минут в гугле можно получить информацию об этом плане - кто и когда его выдвинул. погуглите и вы сразу увидите что это российско-китайский план.для особо одарённых также сообщаю, что подобные совместные планы не просто так появляются. наверняка у россии и китая есть договорённости насчёт совместных боевых действий на территории кндр в случае перехода войны в горячую фазу.', 1.1208179367317421), ('александр иванов, хорошо уже то, что они стали хоть кого-то бояться. поубавилось уверенности в своей безнаказанности.', 1.1279319800135104)]
# 10
# [('а не наоборот ли?', 2.2204460492503131e-16), ('надо дальше поставлять нефть в кндр, тем более если за неё своевремнно платят, разбрасываться покупателями в наше не простое время это преступление. а то что там японцы с сша считают то плевать на них, кто они такие указывать россии?!', 1.0699494211898755), ('юрий королёв, как и у тебя попахивает от приближения войск свободы', 1.098123009259786), ('игорь ,, пардон, встречал разок игоря-не-робота', 1.0993819226674211), ('alexey andreev, а разносчиками вируса являются "самые демократичные дерьмократы из сшп" -- где они появляются и шуршат, там вспыхивает эпидемия "майдана". как борются с эпидемиями -- правильно уничтожают разносчиков -- как быть в данном случае????', 1.1060585715568059), ('абэ кто нам не указ.', 1.1069921320480369), ('а убытки они может нам будут возмещать , тогда без проблем', 1.1094813781659454), ('россия и китай продают нефть в кндр. а в знак благодарности корейцы устраивают ядерные испытания у границы с россией. но из приграничных с кндр районов русские патриоты давно сбежали.', 1.1272843285297343), ('grf, на карту посмотри, у какой границы? они испытывают почти в центре своей страны, и не виноваты, что страна у них маленькая.', 1.1296836910637411), ('кндр - это продукт жизнедеятельности "советского народа", который исчез около 30 лет тому назад (см. преамбулу последней советской конституции). в недалёком будущем кндр исчезнет, как исчезли ссср, чсср, сфрю, гдр и т. п.', 1.1305408240893788)]

# %%
affinity.cluster_centers_indices_[0]
# Out:
# 5
